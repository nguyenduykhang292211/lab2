# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('GlobalLandTemperaturesByCity.csv')

# %%
data
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0        1743-11-01               6.068                          1.737
# 1        1743-12-01                 NaN                            NaN
# 2        1744-01-01                 NaN                            NaN
# 3        1744-02-01                 NaN                            NaN
# 4        1744-03-01                 NaN                            NaN
# ...             ...                 ...                            ...
# 8599207  2013-05-01              11.464                          0.236
# 8599208  2013-06-01              15.043                          0.261
# 8599209  2013-07-01              18.775                          0.193
# 8599210  2013-08-01              18.025                          0.298
# 8599211  2013-09-01                 NaN                            NaN
#
#            City      Country Latitude Longitude
# 0         Århus      Denmark   57.05N    10.33E
# ...

# %%
df=pd.DataFrame(data)

# %%
df.dropna()
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0        1743-11-01               6.068                          1.737
# 5        1744-04-01               5.788                          3.624
# 6        1744-05-01              10.644                          1.283
# 7        1744-06-01              14.051                          1.347
# 8        1744-07-01              16.082                          1.396
# ...             ...                 ...                            ...
# 8599206  2013-04-01               7.710                          0.182
# 8599207  2013-05-01              11.464                          0.236
# 8599208  2013-06-01              15.043                          0.261
# 8599209  2013-07-01              18.775                          0.193
# 8599210  2013-08-01              18.025                          0.298
#
#            City      Country Latitude Longitude
# 0         Århus      Denmark   57.05N    10.33E
# ...

# %%
for i in df.columns:
    print(i,type(df[i][621055]))
# Out:
# dt <class 'str'>
# AverageTemperature <class 'numpy.float64'>
# AverageTemperatureUncertainty <class 'numpy.float64'>
# City <class 'str'>
# Country <class 'str'>
# Latitude <class 'str'>
# Longitude <class 'str'>

# %%
df['dt'] = df['dt'].apply(lambda x: pd.to_datetime(x).strftime('%d/%m/%Y'))

# %%
print(df['dt'])
# Out:
# 0          01/11/1743
# 1          01/12/1743
# 2          01/01/1744
# 3          01/02/1744
# 4          01/03/1744
#               ...
# 8599207    01/05/2013
# 8599208    01/06/2013
# 8599209    01/07/2013
# 8599210    01/08/2013
# 8599211    01/09/2013
# Name: dt, Length: 8599212, dtype: object

# %%
df_=df.copy

# %%
df['dt'] = pd.to_datetime(df['dt'], format='%d/%m/%Y')

# %%
df['dt'].dt.year
# Out:
# 0          1743
# 1          1743
# 2          1744
# 3          1744
# 4          1744
#            ...
# 8599207    2013
# 8599208    2013
# 8599209    2013
# 8599210    2013
# 8599211    2013
# Name: dt, Length: 8599212, dtype: int64

# %%
ax = df['dt'].dt.year.value_counts().sort_values().plot(kind='bar', figsize=(20,12))
plt.show()
